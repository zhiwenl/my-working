# %%
class Node:
    def __init__(self, data, depth=0, lchild=None, rchild=None):
        self.data = data
        self.depth = depth
        self.lchild = lchild
        self.rchild = rchild


class KdTree:
    def __init__(self):
        self.KdTree = None
        self.n = 0
        self.nearest = None

    def create(self, dataSet, depth=0):
        if len(dataSet) > 0:
            m, n = np.shape(dataSet)
            self.n = n - 1
            axis = depth % self.n
            mid = int(m / 2)
            dataSetcopy = sorted(dataSet, key=lambda x: x[axis])
            node = Node(dataSetcopy[mid], depth)
            if depth == 0:
                self.KdTree = node
            node.lchild = self.create(dataSetcopy[:mid], depth+1)
            node.rchild = self.create(dataSetcopy[mid+1:], depth+1)
            return node
        return None

    def preOrder(self, node):
        if node is not None:
            print(node.depth, node.data)
            self.preOrder(node.lchild)
            self.preOrder(node.rchild)

    def search(self, x, count=1):
        nearest = []
        for i in range(count):
            nearest.append([-1, None])
        self.nearest = np.array(nearest)

        def recurve(node):
            if node is not None:
                axis = node.depth % self.n
                daxis = x[axis] - node.data[axis]
                if daxis < 0:
                    recurve(node.lchild)
                else:
                    recurve(node.rchild)

                dist = sqrt(sum((p1 - p2) ** 2 for p1, p2 in zip(x, node.data)))
                for i, d in enumerate(self.nearest):
                    if d[0] < 0 or dist < d[0]:
                        self.nearest = np.insert(self.nearest, i, [dist, node], axis=0)
                        self.nearest = self.nearest[:-1]
                        break

                n = list(self.nearest[:, 0]).count(-1)
                if self.nearest[-n-1, 0] > abs(daxis):
                    if daxis < 0:
                        recurve(node.rchild)
                    else:
                        recurve(node.lchild)

        recurve(self.KdTree)

        knn = self.nearest[:, 1]
        belong = []
        for i in knn:
            belong.append(i.data[-1])
        b = max(set(belong), key=belong.count)

        return self.nearest, b

# %%
import numpy as np
from math import sqrt
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn import preprocessing
min_max_scaler=preprocessing.MinMaxScaler()
from sklearn.datasets import load_wine
iris=load_iris()
iris_sample = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_sample = pd.DataFrame(min_max_scaler.fit_transform(np.array(iris_sample)))
iris_sample['label'] = iris.target
iris_sample=iris_sample.drop_duplicates()

# %%
def run(data):  

        # kdt.preOrder(kdt.KdTree)

    print('epoch..........:',term)
  #  count=0
    Dn = []
    for x in data:
        #plt.scatter(x[0], x[1], c='red', marker='x')  # 测试点
        near, belong = kdt.search(x[:-1], 8)  # 设置临近点的个数
        #print("test:")
       # print(x, "predict:", belong)
       # print("nearest:")
        density = 0
        t,hon,hen,DRL = 0,0,0,0
        for n in near:
            if x[-1] == n[1].data[-1] and (x != n[1].data).any():
                t += 1
                hon += 1

            elif  x[-1] != n[1].data[-1]:
                hen += 1

            density += n[0]  #密度   

        DRL = (hen - hon) / 7  #标签异同差比    
        Ps = t / 7
        Pd = 1 - Ps
        if (Ps==1)|(Ps==0):
            H = 0
        else:
            H = -Ps* np.log2(Ps)-Pd*np.log2(Pd)

       # print(densit)
        if (density <= a): #高密度区域
            if DRL>0:
                Dn.append(list(x))
                print('高密度区噪声')
                print(x)
                for n in near:
                    print(n[1].data,n[0])
                #print('高密度区域噪声')
        else:
            if (H < H_): #低密度单一标签区域
               # print('单一区')
                if DRL>0:
                    Dn.append(list(x))
                    print('低密度单一标签区噪声')
          
            else: #低密度混合标签区域
               # print('混合区')
             #   near2=[]
                hon,hen= 0,0
                dist_hon,dist_hen = 0,0
                for n in near:
                    if x[-1]== n[1].data[-1] and (x != n[1].data).any():
                #        near2.append(n)
               # for n2 in near2:
                 #   if x[-1] == n2[1].data[-1] and (x != n2[1].data).any():
                        hon += 1
                        dist_hon += n[0]
                    elif x[-1] != n[1].data[-1]:
                        hen +=1
                        dist_hen += n[0]
         
                    
                if (dist_hon / hon) / (dist_hen / hen) > 2.0:
                    Dn.append(list(x))
               
                   # print(x)
                   
    #print('标签噪声：',Dn)
    noise_list=noise.values.tolist()
    TP = 0
    for c in Dn:
        if c in noise_list:
            TP += 1
    FP = len(Dn) - TP
    FN = len(noise_list) - TP
    precision= TP / (TP + FP)
    recall= TP / (TP + FN)
    fh= 1.25* (precision * recall) / (0.25*precision + recall) #F0.5值
    re = len(Dn) / len(data)
    print('准确率:',precision)
    print('召回率:',recall)
    print('F0.5值:',fh)
    print('移除率:',re)
    return fh,re

# %%
def run2(data):  
    print('epoch..........:',term)
    Dn = []
    count2=0
    for x in data:
        #plt.scatter(x[0], x[1], c='red', marker='x')  # 测试点
        near, belong = kdt.search(x[:-1], 8)  # 设置临近点的个数
        #print("test:")
       # print(x, "predict:", belong)
       # print("nearest:")
        density = 0
        t,hon,hen,dist_hon,dist_hen,DoD,DRL= 0,0,0,0,0,0,0
        for n in near:
            if x[-1] == n[1].data[-1] and (x != n[1].data).any():
                t += 1
                hon += 1
                dist_hon += n[0]

            elif  x[-1] != n[1].data[-1]:
                hen += 1
                dist_hen += n[0]

            density += n[0]  #密度   

        DoD = abs(dist_hen - dist_hon) #相异性差值(要加绝对值)
        DRL = (hen - hon) / 7  #标签异同差比    
        Ps = t / 7
        Pd = 1 - Ps
        if (Ps==1)|(Ps==0):
            H = 0
        else:
            H = -Ps* np.log2(Ps)-Pd*np.log2(Pd)
      #  print('densit:',density)
       
        if (density <= a): #高密度区域

            if DRL > 0:
                Dn.append(list(x))
                print('高密度区噪声')
                print(x)
                for n in near:
                    print(n[1].data,n[0])
        else:
            if (H < H_): #低密度单一标签区域
        
                if DRL > 0:
                    Dn.append(list(x))
                   # print('低密度单一标签噪声')
   
            else: #低密度混合标签区  
        
              #  print('DoD',DoD)
                DoD_ = density / 7
               # print('DoD阈值:',DoD_)
                if DoD >= DoD_:
                    hon_sa,hen_sa,DoD_sa=0,0,0
                    near2=[]
                    for n in near:
                        if n[0] <= a: #该点到待测点距离小于a
                            near2.append(n)
                    for n2 in near2:
                        if (x[-1]==n2[1].data[-1])and (x != n2[1].data).any():
                            hon_sa +=1
                        elif x[-1] !=n2[1].data[-1]:
                            hen_sa +=1
                    DoD_sa = hen_sa - hon_sa
                    if DoD_sa > 0:        
                        Dn.append(list(x))
                        print('低密度混合标签区噪声')
                      #  print(x)

                    elif DoD_sa ==0 and x[-1] != near[len(near2)][1].data[-1]:
                        Dn.append(list(x))  
                        print('低密度混合标签区噪声')
                      #  print(x)
                        
    noise_list=noise.values.tolist()
    TP = 0
    for c in Dn:
        if c in noise_list:
            TP += 1
    FP = len(Dn) - TP
    FN = len(noise_list) - TP
    precision= TP / (TP + FP)
    recall= TP / (TP + FN)
    fh= 1.25* (precision * recall) / (0.25*precision + recall) #F0.5值
    re = len(Dn) / len(data) #移除率
   # print('准确率:',precision)
 #   print('召回率:',recall)
  #  print('F0.5值:',fh)
 #   print('移除率:',re)
    return fh,re

# %%
# %%time
df=iris_sample
data2=np.array(df.drop('label',axis=1))
dist2=[]
for m in range(0,len(data2)-1):
    for n in range(m+1,len(data2)):
        dist2.append(sqrt(sum((data2[m] - data2[n]) ** 2 )))
a = np.percentile(dist2,10) #密度阈值(%10分位数)
x1 = np.array([[1,1],[1,-1]])
x2 = np.array([1,np.floor(7 / 3)/ 7])
(Ps_,Pd_)=np.linalg.solve(x1,x2)
H_ = -Ps_* np.log2(Ps_)-Pd_*np.log2(Pd_) #标签混合程度阈值

F_list,Re_list,F_list2,Re_list2=[],[],[],[]
for rate in[0.05,0.1,0.2,0.3,0.4]:
#for rate in [0.4]:
    Fh,Re,Fh2,Re2=[],[],[],[]
    for term in range(10): #多次试验取均值

        noise_set=pd.DataFrame(columns=df.columns)
        for r in range(0,(df.label.max()+1)):    
            noise_set=pd.concat([noise_set,df[df.label==r].sample(frac=rate, replace=False,random_state=42)]) #选取噪声比例  
        #bb=df[df.label==1].sample(frac=rate, replace=False) #选取噪声比例
        #cc=df[df.label==2].sample(frac=rate, replace=False) #选取噪声比例

        data_cut=df[~df.index.isin(noise_set.index)]
        no=[]
        for j in range(0,len(noise_set)):
            no.append(int(np.random.rand(1)[0]*(df.label.max()+1))%10)
        noise_set['label2']=no
        noise_set.reset_index(drop=True,inplace=True)
        for l in range(0,len(noise_set)):  #随机替换标签
            if (noise_set.loc[l,'label']==noise_set.loc[l,'label2']):
                noise_set.loc[l,'label2']=(noise_set.loc[l,'label']+1) % (df.label.max()+1)
        noise=noise_set.drop(['label'],axis=1)
        noise.rename(columns={'label2':'label'}, inplace = True)
        data= pd.concat([data_cut,noise],axis=0,ignore_index=True) #含噪声数据集

        data=np.array(data)
        kdt = KdTree()
        kdt.create(data)
        
        result=run(data)
        result2=run2(data)
        Fh.append(result[0])
        Re.append(result[1])
        Fh2.append(result2[0])
        Re2.append(result2[1])
    F_list.append(np.mean(Fh))
    Re_list.append(np.mean(Re))
    F_list2.append(np.mean(Fh2))
    Re_list2.append(np.mean(Re2))
# Out:
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 0
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 1
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6
# 召回率: 1.0
# F0.5值: 0.6521739130434783
# 移除率: 0.06711409395973154
# epoch..........: 2
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 3
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 4
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 5
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 6
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6666666666666666
# 召回率: 1.0
# F0.5值: 0.7142857142857142
# 移除率: 0.06040268456375839
# epoch..........: 7
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6
# 召回率: 1.0
# F0.5值: 0.6521739130434783
# 移除率: 0.06711409395973154
# epoch..........: 8
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6
# 召回率: 1.0
# F0.5值: 0.6521739130434783
# 移除率: 0.06711409395973154
# epoch..........: 9
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.7894736842105263
# 召回率: 1.0
# F0.5值: 0.8241758241758242
# 移除率: 0.12751677852348994
# epoch..........: 0
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 1
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 2
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 3
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 4
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 5
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.7894736842105263
# 召回率: 1.0
# F0.5值: 0.8241758241758242
# 移除率: 0.12751677852348994
# epoch..........: 6
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 7
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8333333333333334
# 召回率: 1.0
# F0.5值: 0.8620689655172415
# 移除率: 0.12080536912751678
# epoch..........: 8
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8235294117647058
# 召回率: 0.9333333333333333
# F0.5值: 0.8433734939759036
# 移除率: 0.11409395973154363
# epoch..........: 9
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8571428571428571
# 召回率: 1.0
# F0.5值: 0.8823529411764707
# 移除率: 0.2348993288590604
# epoch..........: 0
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8787878787878788
# 召回率: 0.9666666666666667
# F0.5值: 0.8950617283950618
# 移除率: 0.2214765100671141
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8823529411764706
# 召回率: 1.0
# F0.5值: 0.9036144578313253
# 移除率: 0.22818791946308725
# epoch..........: 2
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8484848484848485
# 召回率: 0.9333333333333333
# F0.5值: 0.8641975308641975
# 移除率: 0.2214765100671141
# epoch..........: 3
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8787878787878788
# 召回率: 0.9666666666666667
# F0.5值: 0.8950617283950618
# 移除率: 0.2214765100671141
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8823529411764706
# 召回率: 1.0
# F0.5值: 0.9036144578313253
# 移除率: 0.22818791946308725
# epoch..........: 5
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.9090909090909091
# 召回率: 1.0
# F0.5值: 0.9259259259259258
# 移除率: 0.2214765100671141
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8823529411764706
# 召回率: 1.0
# F0.5值: 0.9036144578313253
# 移除率: 0.22818791946308725
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8823529411764706
# 召回率: 1.0
# F0.5值: 0.9036144578313253
# 移除率: 0.22818791946308725
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8571428571428571
# 召回率: 1.0
# F0.5值: 0.8823529411764707
# 移除率: 0.2348993288590604
# epoch..........: 9
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8666666666666667
# 召回率: 0.8666666666666667
# F0.5值: 0.8666666666666667
# 移除率: 0.30201342281879195
# epoch..........: 0
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8571428571428571
# 召回率: 0.8
# F0.5值: 0.8450704225352114
# 移除率: 0.28187919463087246
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.851063829787234
# 召回率: 0.8888888888888888
# F0.5值: 0.8583690987124464
# 移除率: 0.31543624161073824
# epoch..........: 2
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8085106382978723
# 召回率: 0.8444444444444444
# F0.5值: 0.8154506437768241
# 移除率: 0.31543624161073824
# epoch..........: 3
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8478260869565217
# 召回率: 0.8666666666666667
# F0.5值: 0.851528384279476
# 移除率: 0.3087248322147651
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8888888888888888
# 召回率: 0.8888888888888888
# F0.5值: 0.8888888888888888
# 移除率: 0.30201342281879195
# epoch..........: 5
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8604651162790697
# 召回率: 0.8222222222222222
# F0.5值: 0.8525345622119815
# 移除率: 0.28859060402684567
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.85
# 召回率: 0.7555555555555555
# F0.5值: 0.8292682926829268
# 移除率: 0.2684563758389262
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8666666666666667
# 召回率: 0.8666666666666667
# F0.5值: 0.8666666666666667
# 移除率: 0.30201342281879195
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8478260869565217
# 召回率: 0.8666666666666667
# F0.5值: 0.851528384279476
# 移除率: 0.3087248322147651
# epoch..........: 9
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.847457627118644
# 召回率: 0.8333333333333334
# F0.5值: 0.8445945945945946
# 移除率: 0.3959731543624161
# epoch..........: 0
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8448275862068966
# 召回率: 0.8166666666666667
# F0.5值: 0.839041095890411
# 移除率: 0.38926174496644295
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8269230769230769
# 召回率: 0.7166666666666667
# F0.5值: 0.8022388059701492
# 移除率: 0.348993288590604
# epoch..........: 2
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8431372549019608
# 召回率: 0.7166666666666667
# F0.5值: 0.8143939393939393
# 移除率: 0.3422818791946309
# epoch..........: 3
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.7916666666666666
# 召回率: 0.6333333333333333
# F0.5值: 0.7539682539682541
# 移除率: 0.3221476510067114
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8545454545454545
# 召回率: 0.7833333333333333
# F0.5值: 0.8392857142857142
# 移除率: 0.3691275167785235
# epoch..........: 5
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.803921568627451
# 召回率: 0.6833333333333333
# F0.5值: 0.7765151515151516
# 移除率: 0.3422818791946309
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.851063829787234
# 召回率: 0.6666666666666666
# F0.5值: 0.8064516129032258
# 移除率: 0.31543624161073824
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8412698412698413
# 召回率: 0.8833333333333333
# F0.5值: 0.8493589743589743
# 移除率: 0.4228187919463087
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.8524590163934426
# 召回率: 0.8666666666666667
# F0.5值: 0.8552631578947367
# 移除率: 0.40939597315436244
# epoch..........: 9
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# Wall time: 24.7 s

# %%
import mpl_toolkits.axisartist.axislines as axislines
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = [u'SimHei']
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
noise_rate=[5,10,20,30,40]
fig = plt.figure()
ax1 = axislines.Subplot(fig, 1,1,1)
fig.add_subplot(ax1)
ax1.set_xticks(noise_rate)
ax1.axis([0,40,0,1])
plt.plot(noise_rate,F_list,'ro-',label='IM_DDF')
plt.plot(noise_rate,F_list2,'b*-.',label='DDF')
plt.xlabel('噪声比例/%')
plt.ylabel('F0.5')
plt.title('不同噪声下的F0.5值',fontsize=16)
plt.legend()
plt.show()

# %%
fig2 = plt.figure()
ax2 = axislines.Subplot(fig2, 1,1,1)
fig2.add_subplot(ax2)
ax2.set_xticks([5,10,20,30,40])
ax2.set_yticks([0,0.2,0.4,0.6,0.8])
ax2.axis([0,40,0,0.8])
plt.plot(noise_rate,Re_list,'ro-',label='IM_DDF')
plt.plot(noise_rate,Re_list2,'b*-.',label='DDF')
plt.xlabel('噪声比例/%')
plt.ylabel('Re')
plt.title('不同噪声下的过滤值Re',fontsize=16)
plt.legend()
plt.show()

# %%
Re_list,Re_list2
# Out:
# ([0.062416107382550344,
#   0.1214765100671141,
#   0.22684563758389262,
#   0.2993288590604027,
#   0.36577181208053694],
#  [0.06711409395973154,
#   0.1268456375838926,
#   0.23825503355704697,
#   0.3395973154362416,
#   0.4543624161073826])

# %%
F_list,F_list2
# Out:
# ([0.6956521739130435,
#   0.8526207900948244,
#   0.8959410627258491,
#   0.8525972010700565,
#   0.818111130077515],
#  [0.6521739130434783,
#   0.8222180118731843,
#   0.8663286004056797,
#   0.8121418257965367,
#   0.742313567792354])
