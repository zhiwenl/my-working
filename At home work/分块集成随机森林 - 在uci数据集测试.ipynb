# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split

# %%
# %%time
rf1=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=1,max_features='auto')
rf2=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=50,max_features='log2')
rf3=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=1,max_features=0.7)
rf4=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=50,max_features='auto')
rf5=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=1,max_features='log2')
rf6=RandomForestClassifier(n_estimators=100,random_state=42,min_samples_leaf=50,max_features=0.7) #生成6个不同的分类器

iris = load_iris()
iris_sample = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_sample = pd.DataFrame(min_max_scaler.fit_transform(np.array(iris_sample)))
iris_sample['label'] = iris.target

Dn=[]  
for i in range(3): #生成3个不同的数据集分块
    subset1=data.sample(frac=0.25,random_state=i)   #第1个数据子集
    subset1_=data[~data.index.isin(list(subset1.index))] #第1个数据子集的补集
    subset2=data.sample(frac=0.25)   #第2个数据子集
    subset2_=data[~data.index.isin(list(subset2.index))] #第2个数据子集的补集
    subset3=data.sample(frac=0.25)   #第3个数据子集
    subset3_=data[~data.index.isin(list(subset3.index))] #第3个数据子集的补集
    subset4=data.sample(frac=0.25)   #第4个数据子集
    subset4_=data[~data.index.isin(list(subset4.index))] #第4个数据子集的补集
    X_train1,y_train1=subset1_.drop(['用户ID','用水性质'],axis=1),subset1_.水表口径
    X_test1,y_test1=subset1.drop(['用户ID','用水性质'],axis=1),subset1.水表口径  
    X_train2,y_train2=subset2_.drop(['用户ID','用水性质'],axis=1),subset2_.水表口径
    X_test2,y_test2=subset2.drop(['用户ID','用水性质'],axis=1),subset2.水表口径  
    X_train3,y_train3=subset3_.drop(['用户ID','用水性质'],axis=1),subset3_.水表口径
    X_test3,y_test3=subset3.drop(['用户ID','用水性质'],axis=1),subset3.水表口径  
    X_train4,y_train4=subset4_.drop(['用户ID','用水性质'],axis=1),subset4_.水表口径
    X_test4,y_test4=subset4.drop(['用户ID','用水性质'],axis=1),subset4.水表口径  
    rf1.fit(X_train1,y_train1)  # 训练第一个数据子集的补集
    rf2.fit(X_train1,y_train1)
    rf3.fit(X_train1,y_train1)
    rf4.fit(X_train1,y_train1)
    rf5.fit(X_train1,y_train1)
    rf6.fit(X_train1,y_train1)
    for i in X_test1.index:
        err_count=0
        if int(rf1.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if int(rf2.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if int(rf3.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if int(rf4.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if int(rf5.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if int(rf6.predict(X_test1[X_test1.index==i])) != int(y_test1[y_test1.index==i]) : 
            err_count+=1
        if err_count >3:
            Dn.append(i)


    rf1.fit(X_train2,y_train2)  # 训练第二个数据子集的补集
    rf2.fit(X_train2,y_train2)
    rf3.fit(X_train2,y_train2)
    rf4.fit(X_train2,y_train2)
    rf5.fit(X_train2,y_train2)
    rf6.fit(X_train2,y_train2)
    for i in X_test2.index:
        err_count=0
        if int(rf1.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if int(rf2.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if int(rf3.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if int(rf4.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if int(rf5.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if int(rf6.predict(X_test2[X_test2.index==i])) != int(y_test2[y_test2.index==i]) : 
            err_count+=1
        if err_count >3:
            Dn.append(i)
   

    rf1.fit(X_train3,y_train3)  # 训练第三个数据子集的补集
    rf2.fit(X_train3,y_train3)
    rf3.fit(X_train3,y_train3)
    rf4.fit(X_train3,y_train3)
    rf5.fit(X_train3,y_train3)
    rf6.fit(X_train3,y_train3)
    for i in X_test3.index:
        err_count=0
        if int(rf1.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if int(rf2.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if int(rf3.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if int(rf4.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if int(rf5.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if int(rf6.predict(X_test3[X_test3.index==i])) != int(y_test3[y_test3.index==i]) : 
            err_count+=1
        if err_count >3:
            Dn.append(i)


    rf1.fit(X_train4,y_train4)  # 训练第四个数据子集的补集
    rf2.fit(X_train4,y_train4)
    rf3.fit(X_train4,y_train4)
    rf4.fit(X_train4,y_train4)
    rf5.fit(X_train4,y_train4)
    rf6.fit(X_train4,y_train4)
    for i in X_test4.index:
        err_count=0
        if int(rf1.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if int(rf2.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if int(rf3.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if int(rf4.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if int(rf5.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if int(rf6.predict(X_test4[X_test4.index==i])) != int(y_test4[y_test4.index==i]) : 
            err_count+=1
        if err_count >3:
            Dn.append(i)
# Out:
# Wall time: 5min 9s

# %%
from collections import Counter   #引入Counter
b = dict(Counter(Dn))
c=([key for key,value in b.items()if value > 2])#三个疑似噪声集都出现的元素

# %%
noise_set= df[df.index.isin(c)] #最终噪声集

# %%
len(noise_set)
# Out:
# 36

# %%
noise_set
# Out:
#             用户ID  水表口径      用水性质        1        2        3        4        5  \
# 45    3202201422    20      商贸服务    290.0    265.0    218.0    260.0    268.0
# 51    3202210822    15      商贸服务    595.0    647.0    424.0    532.0    658.0
# 118   3203407022    15      商贸服务    184.0    263.0    184.0    258.0    261.0
# 126   3203602122   100      学校部队  36000.0  27416.0  30258.0  43176.0  31347.0
# 198   3204736322    20      商贸服务      7.0     10.0      5.0      6.0      8.0
# 348   3207702522    25      居民合表    152.0    114.0    107.0    153.0    167.0
# 357   3207707222    50      商贸服务    394.0    331.0    394.0    458.0    468.0
# 374   3208103222   100      学校部队   1039.0    785.0    313.0    433.0    434.0
# 434   3208524022   100  机关团体事业单位    705.0    828.0    174.0      6.0      8.0
# 437   3208603722   100      工矿企业    287.0    565.0    599.0    618.0    692.0
# 511   3211101422    40      工矿企业     70.0     85.0     53.0     70.0     88.0
# ...
