# %%
class Node:
    def __init__(self, data, depth=0, lchild=None, rchild=None):
        self.data = data
        self.depth = depth
        self.lchild = lchild
        self.rchild = rchild


class KdTree:
    def __init__(self):
        self.KdTree = None
        self.n = 0
        self.nearest = None

    def create(self, dataSet, depth=0):
        if len(dataSet) > 0:
            m, n = np.shape(dataSet)
            self.n = n - 1
            axis = depth % self.n
            mid = int(m / 2)
            dataSetcopy = sorted(dataSet, key=lambda x: x[axis])
            node = Node(dataSetcopy[mid], depth)
            if depth == 0:
                self.KdTree = node
            node.lchild = self.create(dataSetcopy[:mid], depth+1)
            node.rchild = self.create(dataSetcopy[mid+1:], depth+1)
            return node
        return None

    def preOrder(self, node):
        if node is not None:
            print(node.depth, node.data)
            self.preOrder(node.lchild)
            self.preOrder(node.rchild)

    def search(self, x, count=1):
        nearest = []
        for i in range(count):
            nearest.append([-1, None])
        self.nearest = np.array(nearest)

        def recurve(node):
            if node is not None:
                axis = node.depth % self.n
                daxis = x[axis] - node.data[axis]
                if daxis < 0:
                    recurve(node.lchild)
                else:
                    recurve(node.rchild)

                dist = sqrt(sum((p1 - p2) ** 2 for p1, p2 in zip(x, node.data)))
                for i, d in enumerate(self.nearest):
                    if d[0] < 0 or dist < d[0]:
                        self.nearest = np.insert(self.nearest, i, [dist, node], axis=0)
                        self.nearest = self.nearest[:-1]
                        break

                n = list(self.nearest[:, 0]).count(-1)
                if self.nearest[-n-1, 0] > abs(daxis):
                    if daxis < 0:
                        recurve(node.rchild)
                    else:
                        recurve(node.lchild)

        recurve(self.KdTree)

        knn = self.nearest[:, 1]
        belong = []
        for i in knn:
            belong.append(i.data[-1])
        b = max(set(belong), key=belong.count)

        return self.nearest, b

# %%
import numpy as np
from math import sqrt
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn import preprocessing
min_max_scaler=preprocessing.MinMaxScaler()
from sklearn.datasets import load_wine
iris=load_iris()
iris_sample = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_sample = pd.DataFrame(min_max_scaler.fit_transform(np.array(iris_sample)))
iris_sample['label'] = iris.target
iris_sample=iris_sample.drop_duplicates()

# %%
def run(data):  

        # kdt.preOrder(kdt.KdTree)

    print('epoch..........:',term)
  #  count=0
    Dn = []
    for x in data:
        #plt.scatter(x[0], x[1], c='red', marker='x')  # 测试点
        near, belong = kdt.search(x[:-1], 8)  # 设置临近点的个数
        #print("test:")
       # print(x, "predict:", belong)
       # print("nearest:")
        density = 0
        t,hon,hen,DRL = 0,0,0,0
        for n in near:
            if x[-1] == n[1].data[-1] and (x != n[1].data).any():
                t += 1
                hon += 1

            elif  x[-1] != n[1].data[-1]:
                hen += 1

            density += n[0]  #密度   

        DRL = (hen - hon) / 7  #标签异同差比    
        Ps = t / 7
        Pd = 1 - Ps
        if (Ps==1)|(Ps==0):
            H = 0
        else:
            H = -Ps* np.log2(Ps)-Pd*np.log2(Pd)

       # print(densit)
        if (density <= a): #高密度区域
            if DRL>0:
                Dn.append(list(x))
                print('高密度区噪声')
                print(x)
                for n in near:
                    print(n[1].data,n[0])
                #print('高密度区域噪声')
        else:
            if (H < H_): #低密度单一标签区域
               # print('单一区')
                if DRL>0:
                    Dn.append(list(x))
                    print('低密度单一标签区噪声')
          
            else: #低密度混合标签区域
               # print('混合区')
             #   near2=[]
                hon,hen= 0,0
                dist_hon,dist_hen = 0,0
                for n in near:
                    if x[-1]== n[1].data[-1] and (x != n[1].data).any():
                #        near2.append(n)
               # for n2 in near2:
                 #   if x[-1] == n2[1].data[-1] and (x != n2[1].data).any():
                        hon += 1
                        dist_hon += n[0]
                    elif x[-1] != n[1].data[-1]:
                        hen +=1
                        dist_hen += n[0]
         
                    
                if (dist_hon / hon) / (dist_hen / hen) > 1.0:
                    Dn.append(list(x))
               
                   # print(x)
                   
    #print('标签噪声：',Dn)
    noise_list=noise.values.tolist()
    TP = 0
    for c in Dn:
        if c in noise_list:
            TP += 1
    FP = len(Dn) - TP
    FN = len(noise_list) - TP
    precision= TP / (TP + FP)
    recall= TP / (TP + FN)
    fh= 1.25* (precision * recall) / (0.25*precision + recall) #F0.5值
    re = len(Dn) / len(data)
    print('准确率:',precision)
    print('召回率:',recall)
    print('F0.5值:',fh)
    print('移除率:',re)
    return fh,re

# %%
def run2(data):  
    print('epoch..........:',term)
    Dn = []
    count2=0
    for x in data:
        #plt.scatter(x[0], x[1], c='red', marker='x')  # 测试点
        near, belong = kdt.search(x[:-1], 8)  # 设置临近点的个数
        #print("test:")
       # print(x, "predict:", belong)
       # print("nearest:")
        density = 0
        t,hon,hen,dist_hon,dist_hen,DoD,DRL= 0,0,0,0,0,0,0
        for n in near:
            if x[-1] == n[1].data[-1] and (x != n[1].data).any():
                t += 1
                hon += 1
                dist_hon += n[0]

            elif  x[-1] != n[1].data[-1]:
                hen += 1
                dist_hen += n[0]

            density += n[0]  #密度   

        DoD = abs(dist_hen - dist_hon) #相异性差值(要加绝对值)
        DRL = (hen - hon) / 7  #标签异同差比    
        Ps = t / 7
        Pd = 1 - Ps
        if (Ps==1)|(Ps==0):
            H = 0
        else:
            H = -Ps* np.log2(Ps)-Pd*np.log2(Pd)
      #  print('densit:',density)
       
        if (density <= a): #高密度区域

            if DRL > 0:
                Dn.append(list(x))
                print('高密度区噪声')
                print(x)
                for n in near:
                    print(n[1].data,n[0])
        else:
            if (H < H_): #低密度单一标签区域
        
                if DRL > 0:
                    Dn.append(list(x))
                   # print('低密度单一标签噪声')
   
            else: #低密度混合标签区  
        
              #  print('DoD',DoD)
                DoD_ = density / 7
               # print('DoD阈值:',DoD_)
                if DoD >= DoD_:
                    hon_sa,hen_sa,DoD_sa=0,0,0
                    near2=[]
                    for n in near:
                        if n[0] <= a: #该点到待测点距离小于a
                            near2.append(n)
                    for n2 in near2:
                        if (x[-1]==n2[1].data[-1])and (x != n2[1].data).any():
                            hon_sa +=1
                        elif x[-1] !=n2[1].data[-1]:
                            hen_sa +=1
                    DoD_sa = hen_sa - hon_sa
                    if DoD_sa > 0:        
                        Dn.append(list(x))
                        print('低密度混合标签区噪声')
                      #  print(x)

                    elif DoD_sa ==0 and x[-1] != near[len(near2)][1].data[-1]:
                        Dn.append(list(x))  
                        print('低密度混合标签区噪声')
                      #  print(x)
                        
    noise_list=noise.values.tolist()
    TP = 0
    for c in Dn:
        if c in noise_list:
            TP += 1
    FP = len(Dn) - TP
    FN = len(noise_list) - TP
    precision= TP / (TP + FP)
    recall= TP / (TP + FN)
    fh= 1.25* (precision * recall) / (0.25*precision + recall) #F0.5值
    re = len(Dn) / len(data) #移除率
   # print('准确率:',precision)
 #   print('召回率:',recall)
  #  print('F0.5值:',fh)
 #   print('移除率:',re)
    return fh,re

# %%
# %%time
df=iris_sample
data2=np.array(df.drop('label',axis=1))
dist2=[]
for m in range(0,len(data2)-1):
    for n in range(m+1,len(data2)):
        dist2.append(sqrt(sum((data2[m] - data2[n]) ** 2 )))
a = np.percentile(dist2,10) #密度阈值(%10分位数)
x1 = np.array([[1,1],[1,-1]])
x2 = np.array([1,np.floor(7 / 3)/ 7])
(Ps_,Pd_)=np.linalg.solve(x1,x2)
H_ = -Ps_* np.log2(Ps_)-Pd_*np.log2(Pd_) #标签混合程度阈值

F_list,Re_list,F_list2,Re_list2=[],[],[],[]
for rate in[0.05,0.1,0.2,0.3,0.4]:
#for rate in [0.4]:
    Fh,Re,Fh2,Re2=[],[],[],[]
    for term in range(10): #多次试验取均值

        noise_set=pd.DataFrame(columns=df.columns)
        for r in range(0,(df.label.max()+1)):    
            noise_set=pd.concat([noise_set,df[df.label==r].sample(frac=rate, replace=False,random_state=42)]) #选取噪声比例  
        #bb=df[df.label==1].sample(frac=rate, replace=False) #选取噪声比例
        #cc=df[df.label==2].sample(frac=rate, replace=False) #选取噪声比例

        data_cut=df[~df.index.isin(noise_set.index)]
        no=[]
        for j in range(0,len(noise_set)):
            no.append(int(np.random.rand(1)[0]*(df.label.max()+1))%10)
        noise_set['label2']=no
        noise_set.reset_index(drop=True,inplace=True)
        for l in range(0,len(noise_set)):  #随机替换标签
            if (noise_set.loc[l,'label']==noise_set.loc[l,'label2']):
                noise_set.loc[l,'label2']=(noise_set.loc[l,'label']+1) % (df.label.max()+1)
        noise=noise_set.drop(['label'],axis=1)
        noise.rename(columns={'label2':'label'}, inplace = True)
        data= pd.concat([data_cut,noise],axis=0,ignore_index=True) #含噪声数据集

        data=np.array(data)
        kdt = KdTree()
        kdt.create(data)
        
        result=run(data)
        result2=run2(data)
        Fh.append(result[0])
        Re.append(result[1])
        Fh2.append(result2[0])
        Re2.append(result2[1])
    F_list.append(np.mean(Fh))
    Re_list.append(np.mean(Re))
    F_list2.append(np.mean(Fh2))
    Re_list2.append(np.mean(Re2))
# Out:
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 0
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 1
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 2
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 3
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 4
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 5
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 6
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 7
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 8
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.42857142857142855
# 召回率: 1.0
# F0.5值: 0.48387096774193544
# 移除率: 0.09395973154362416
# epoch..........: 9
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 0
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 1
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 2
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 3
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 4
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 5
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 6
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 7
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 8
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6521739130434783
# 召回率: 1.0
# F0.5值: 0.7009345794392524
# 移除率: 0.15436241610738255
# epoch..........: 9
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5686274509803921
# 召回率: 0.9666666666666667
# F0.5值: 0.6196581196581196
# 移除率: 0.3422818791946309
# epoch..........: 0
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5882352941176471
# 召回率: 1.0
# F0.5值: 0.6410256410256411
# 移除率: 0.3422818791946309
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5769230769230769
# 召回率: 1.0
# F0.5值: 0.6302521008403361
# 移除率: 0.348993288590604
# epoch..........: 2
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5686274509803921
# 召回率: 0.9666666666666667
# F0.5值: 0.6196581196581196
# 移除率: 0.3422818791946309
# epoch..........: 3
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5769230769230769
# 召回率: 1.0
# F0.5值: 0.6302521008403361
# 移除率: 0.348993288590604
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5714285714285714
# 召回率: 0.9333333333333333
# F0.5值: 0.6194690265486725
# 移除率: 0.3288590604026846
# epoch..........: 5
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5882352941176471
# 召回率: 1.0
# F0.5值: 0.6410256410256411
# 移除率: 0.3422818791946309
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5882352941176471
# 召回率: 1.0
# F0.5值: 0.6410256410256411
# 移除率: 0.3422818791946309
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5769230769230769
# 召回率: 1.0
# F0.5值: 0.6302521008403361
# 移除率: 0.348993288590604
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5769230769230769
# 召回率: 1.0
# F0.5值: 0.6302521008403361
# 移除率: 0.348993288590604
# epoch..........: 9
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6515151515151515
# 召回率: 0.9555555555555556
# F0.5值: 0.6957928802588995
# 移除率: 0.4429530201342282
# epoch..........: 0
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6567164179104478
# 召回率: 0.9777777777777777
# F0.5值: 0.7028753993610224
# 移除率: 0.44966442953020136
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6285714285714286
# 召回率: 0.9777777777777777
# F0.5值: 0.6769230769230768
# 移除率: 0.4697986577181208
# epoch..........: 2
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6212121212121212
# 召回率: 0.9111111111111111
# F0.5值: 0.663430420711974
# 移除率: 0.4429530201342282
# epoch..........: 3
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6417910447761194
# 召回率: 0.9555555555555556
# F0.5值: 0.6869009584664536
# 移除率: 0.44966442953020136
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6349206349206349
# 召回率: 0.8888888888888888
# F0.5值: 0.6734006734006734
# 移除率: 0.4228187919463087
# epoch..........: 5
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6268656716417911
# 召回率: 0.9333333333333333
# F0.5值: 0.6709265175718852
# 移除率: 0.44966442953020136
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6461538461538462
# 召回率: 0.9333333333333333
# F0.5值: 0.6885245901639343
# 移除率: 0.436241610738255
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6212121212121212
# 召回率: 0.9111111111111111
# F0.5值: 0.663430420711974
# 移除率: 0.4429530201342282
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.6290322580645161
# 召回率: 0.8666666666666667
# F0.5值: 0.6655290102389078
# 移除率: 0.4161073825503356
# epoch..........: 9
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 0
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5517241379310345
# 召回率: 0.8
# F0.5值: 0.588235294117647
# 移除率: 0.5838926174496645
# epoch..........: 0
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 1
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5591397849462365
# 召回率: 0.8666666666666667
# F0.5值: 0.6018518518518519
# 移除率: 0.6241610738255033
# epoch..........: 1
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 2
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5670103092783505
# 召回率: 0.9166666666666666
# F0.5值: 0.6138392857142856
# 移除率: 0.6510067114093959
# epoch..........: 2
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 3
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5833333333333334
# 召回率: 0.9333333333333333
# F0.5值: 0.6306306306306307
# 移除率: 0.6442953020134228
# epoch..........: 3
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 4
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5894736842105263
# 召回率: 0.9333333333333333
# F0.5值: 0.6363636363636362
# 移除率: 0.6375838926174496
# epoch..........: 4
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 5
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5684210526315789
# 召回率: 0.9
# F0.5值: 0.6136363636363635
# 移除率: 0.6375838926174496
# epoch..........: 5
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 6
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.574468085106383
# 召回率: 0.9
# F0.5值: 0.6192660550458715
# 移除率: 0.6308724832214765
# epoch..........: 6
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 7
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5806451612903226
# 召回率: 0.9
# F0.5值: 0.625
# 移除率: 0.6241610738255033
# epoch..........: 7
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 8
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5876288659793815
# 召回率: 0.95
# F0.5值: 0.6361607142857143
# 移除率: 0.6510067114093959
# epoch..........: 8
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# epoch..........: 9
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 低密度单一标签区噪声
# 准确率: 0.5543478260869565
# 召回率: 0.85
# F0.5值: 0.5957943925233645
# 移除率: 0.6174496644295302
# epoch..........: 9
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# 低密度混合标签区噪声
# Wall time: 29.2 s

# %%
import mpl_toolkits.axisartist.axislines as axislines
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = [u'SimHei']
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
noise_rate=[5,10,20,30,40]
fig = plt.figure()
ax1 = axislines.Subplot(fig, 1,1,1)
fig.add_subplot(ax1)
ax1.set_xticks(noise_rate)
ax1.axis([0,40,0,1])
plt.plot(noise_rate,F_list,'ro-',label='IM_DDF')
plt.plot(noise_rate,F_list2,'b*-.',label='DDF')
plt.xlabel('噪声比例/%')
plt.ylabel('F0.5')
plt.title('不同噪声下的F0.5值',fontsize=16)
plt.legend()
plt.show()

# %%
fig2 = plt.figure()
ax2 = axislines.Subplot(fig2, 1,1,1)
fig2.add_subplot(ax2)
ax2.set_xticks([5,10,20,30,40])
ax2.set_yticks([0,0.2,0.4,0.6,0.8])
ax2.axis([0,40,0,0.8])
plt.plot(noise_rate,Re_list,'ro-',label='IM_DDF')
plt.plot(noise_rate,Re_list2,'b*-.',label='DDF')
plt.xlabel('噪声比例/%')
plt.ylabel('Re')
plt.title('不同噪声下的过滤值Re',fontsize=16)
plt.legend()
plt.show()

# %%
Re_list,Re_list2
# Out:
# ([0.09395973154362416,
#   0.15436241610738258,
#   0.3436241610738255,
#   0.44228187919463097,
#   0.6302013422818792],
#  [0.06577181208053692,
#   0.1268456375838926,
#   0.23691275167785236,
#   0.33691275167785234,
#   0.4583892617449664])

# %%
F_list,F_list2
# Out:
# ([0.4838709677419354,
#   0.7009345794392524,
#   0.6302870592303179,
#   0.6787733947808801,
#   0.6160778224169365],
#  [0.6407867494824017,
#   0.8222180118731843,
#   0.8645299249737286,
#   0.8090029294678324,
#   0.7507813111687175])
